# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import urllib

# %%
url = "https://drive.google.com/uc?id=10wSR0Ln-rpkbBpJLq_LLY7ESm_8XjrnC"
geolocation_df = pd.read_csv(url)
geolocation_df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
customers_df = pd.read_csv("https://raw.githubusercontent.com/DiegoCoding07/Dicoding-Submission/refs/heads/main/E-Commerce%20Public%20Dataset%20Partial%200/customers_dataset.csv")
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
sellers_df = pd.read_csv("https://raw.githubusercontent.com/DiegoCoding07/Dicoding-Submission/refs/heads/main/E-Commerce%20Public%20Dataset%20Partial%200/sellers_dataset.csv")
sellers_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
order_items_df = pd.read_csv("https://raw.githubusercontent.com/DiegoCoding07/Dicoding-Submission/refs/heads/main/E-Commerce%20Public%20Dataset%20Partial%200/order_items_dataset.csv")
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
order_payments_df = pd.read_csv("https://raw.githubusercontent.com/DiegoCoding07/Dicoding-Submission/refs/heads/main/E-Commerce%20Public%20Dataset%20Partial%200/order_payments_dataset.csv")
order_payments_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_reviews_df = pd.read_csv("https://raw.githubusercontent.com/DiegoCoding07/Dicoding-Submission/refs/heads/main/E-Commerce%20Public%20Dataset%20Partial%200/order_reviews_dataset.csv")
order_reviews_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
orders_df = pd.read_csv("https://raw.githubusercontent.com/DiegoCoding07/Dicoding-Submission/refs/heads/main/E-Commerce%20Public%20Dataset%20Partial%200/orders_dataset.csv")
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
product_cnt_df = pd.read_csv("https://raw.githubusercontent.com/DiegoCoding07/Dicoding-Submission/refs/heads/main/E-Commerce%20Public%20Dataset%20Partial%200/product_category_name_translation.csv")
product_cnt_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
products_df = pd.read_csv("https://raw.githubusercontent.com/DiegoCoding07/Dicoding-Submission/refs/heads/main/E-Commerce%20Public%20Dataset%20Partial%200/products_dataset.csv")
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
print(geolocation_df.info(), "\n")
print(customers_df.info(), "\n")
print(sellers_df.info(), "\n")
print(order_items_df.info(), "\n")
print(order_payments_df.info(), "\n")
print(order_reviews_df.info(), "\n")
print(orders_df.info(), "\n")
print(product_cnt_df.info(), "\n")
print(products_df.info(), "\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
# ...

# %%
print("Memeriksa data null pada geolocation: \n", geolocation_df.isna().sum(), "\n")
print("Memeriksa data null pada customers: \n", customers_df.isna().sum(), "\n")
print("Memeriksa data null pada sellers: \n", sellers_df.isna().sum(), "\n")
print("Memeriksa data null pada order_items: \n", order_items_df.isna().sum(), "\n")
print("Memeriksa data null pada order_payments: \n", order_payments_df.isna().sum(), "\n")
print("Memeriksa data null pada order_reviews: \n", order_reviews_df.isna().sum(), "\n")
print("Memeriksa data null pada orders: \n", orders_df.isna().sum(), "\n")
print("Memeriksa data null pada product_cnt: \n", product_cnt_df.isna().sum(), "\n")
print("Memeriksa data null pada products: \n", products_df.isna().sum(), "\n")
# Out:
# Memeriksa data null pada geolocation:
#  geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64
#
# Memeriksa data null pada customers:
#  customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
#
# Memeriksa data null pada sellers:
#  seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64
#
# Memeriksa data null pada order_items:
#  order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64
#
# Memeriksa data null pada order_payments:
#  order_id                0
# payment_sequential      0
# payment_type            0
# ...

# %%
print("Memeriksa duplikasi geolocation: ", geolocation_df.duplicated().sum(), "\n")
print("Memeriksa duplikasi pada customers: \n", customers_df.duplicated().sum(), "\n")
print("Memeriksa duplikasi pada sellers: \n", sellers_df.duplicated().sum(), "\n")
print("Memeriksa duplikasi pada order_items: \n", order_items_df.duplicated().sum(), "\n")
print("Memeriksa duplikasi pada order_payments: \n", order_payments_df.duplicated().sum(), "\n")
print("Memeriksa duplikasi pada order_reviews: \n", order_reviews_df.duplicated().sum(), "\n")
print("Memeriksa duplikasi pada orders: \n", orders_df.duplicated().sum(), "\n")
print("Memeriksa duplikasi pada product_cnt: \n", product_cnt_df.duplicated().sum(), "\n")
print("Memeriksa duplikasi pada products: \n", products_df.duplicated().sum(), "\n")
# Out:
# Memeriksa duplikasi geolocation:  261831
#
# Memeriksa duplikasi pada customers:
#  0
#
# Memeriksa duplikasi pada sellers:
#  0
#
# Memeriksa duplikasi pada order_items:
#  0
#
# Memeriksa duplikasi pada order_payments:
#  0
#
# Memeriksa duplikasi pada order_reviews:
#  0
#
# Memeriksa duplikasi pada orders:
#  0
#
# Memeriksa duplikasi pada product_cnt:
#  0
#
# Memeriksa duplikasi pada products:
#  0

# %%
print("Mendeskripsikan data pada geolocation:\n", geolocation_df.describe(include="all"), "\n")
print("Mendeskripsikan data pada customers: \n", customers_df.describe(include="all"), "\n")
print("Mendeskripsikan data pada sellers: \n", sellers_df.describe(include="all"), "\n")
print("Mendeskripsikan data pada order_items: \n", order_items_df.describe(include="all"), "\n")
print("Mendeskripsikan data pada order_payments: \n", order_payments_df.describe(include="all"), "\n")
print("Mendeskripsikan data pada order_reviews: \n", order_reviews_df.describe(include="all"), "\n")
print("Mendeskripsikan data pada orders: \n", orders_df.describe(include="all"), "\n")
print("Mendeskripsikan data pada product_cnt: \n", product_cnt_df.describe(include="all"), "\n")
print("Mendeskripsikan data pada products: \n", products_df.describe(include="all"), "\n")
# Out:
# Mendeskripsikan data pada geolocation:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# count                  1.000163e+06     1.000163e+06     1.000163e+06
# unique                          NaN              NaN              NaN
# top                             NaN              NaN              NaN
# freq                            NaN              NaN              NaN
# mean                   3.657417e+04    -2.117615e+01    -4.639054e+01
# std                    3.054934e+04     5.715866e+00     4.269748e+00
# min                    1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                    1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                    2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                    6.350400e+04    -1.997962e+01    -4.376771e+01
# max                    9.999000e+04     4.506593e+01     1.211054e+02
#
#        geolocation_city geolocation_state
# count           1000163           1000163
# ...

# %%
geolocation_df.drop_duplicates(inplace=True)

print("Memeriksa duplikasi geolocation: ", geolocation_df.duplicated().sum())
# Out:
# Memeriksa duplikasi geolocation:  0

# %%
#Customers#

# %%
#Sellers#

# %%
datetime_columns = ["shipping_limit_date"]

for column in datetime_columns:
  order_items_df[column] = pd.to_datetime(order_items_df[column])

order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %%
#Order_payments#

# %%
order_reviews_df[order_reviews_df.review_comment_title.isna()]
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
order_reviews_df.drop("review_comment_title", axis=1, inplace=True)

# %%
order_reviews_df[order_reviews_df.review_comment_message.isna()]
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 5      15197aa66ff4d0650b5434f1b46cda19  b18dcdf73be66366873cd26c5724d1dc
# 6      07f9bee5d1b850860defd761afa7ff16  e48aa0d2dcec3a2e87348811bcfdf22b
# ...                                 ...                               ...
# 99217  c6b270c61f67c9f7cb07d84ea8aeaf8b  48f7ee67313eda32bfcf5b9c1dd9522d
# 99218  af2dc0519de6e0720ef0c74292fb4114  d699c734a0b1c8111f2272a3f36d398c
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
#
#        review_score review_comment_message review_creation_date  \
# ...

# %%
order_reviews_df["review_comment_message"].fillna("No Comment", inplace=True)
print("Memeriksa data null pada order_reviews: \n", order_reviews_df.isna().sum())
# Out:
# Memeriksa data null pada order_reviews:
#  review_id                  0
# order_id                   0
# review_score               0
# review_comment_message     0
# review_creation_date       0
# review_answer_timestamp    0
# dtype: int64
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_28876\1724136273.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   order_reviews_df["review_comment_message"].fillna("No Comment", inplace=True)

# %%
datetime_columns = ["review_creation_date"]

for column in datetime_columns:
  order_reviews_df[column] = pd.to_datetime(order_reviews_df[column])

order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_message   99224 non-null  object
#  4   review_creation_date     99224 non-null  datetime64[ns]
#  5   review_answer_timestamp  99224 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 4.5+ MB

# %%
print(orders_df["order_status"].value_counts())
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %%
delivered_percentage = (orders_df["order_status"].value_counts()["delivered"] / len(orders_df)) * 100
print("Mengambil data delivered diperoleh sejumlah " + str(round(delivered_percentage, 2)) + "% of data")
# Out:
# Mengambil data delivered diperoleh sejumlah 97.02% of data

# %%
delivered_orders = orders_df.drop(orders_df[orders_df['order_status'] != 'delivered'].index)

orders_df = delivered_orders
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders_df.isna().sum()
# Out:
# order_id                          0
# customer_id                       0
# order_status                      0
# order_purchase_timestamp          0
# order_approved_at                14
# order_delivered_carrier_date      2
# order_delivered_customer_date     8
# order_estimated_delivery_date     0
# dtype: int64

# %%
orders_df = orders_df.dropna(subset=["order_approved_at", "order_delivered_carrier_date", "order_delivered_customer_date"])
orders_df.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %%
datetime_columns = ["order_purchase_timestamp", "order_approved_at", "order_delivered_carrier_date", "order_delivered_customer_date", "order_estimated_delivery_date"]

for column in datetime_columns:
  orders_df[column] = pd.to_datetime(orders_df[column])

orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 96455 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       96455 non-null  object
#  1   customer_id                    96455 non-null  object
#  2   order_status                   96455 non-null  object
#  3   order_purchase_timestamp       96455 non-null  datetime64[ns]
#  4   order_approved_at              96455 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   96455 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96455 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  96455 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.6+ MB
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_28876\3109534557.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
orders_df["delivered_on_time"] = np.where(orders_df["order_delivered_customer_date"] <= orders_df["order_estimated_delivery_date"], "On Time", "Late")
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_28876\124810739.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orders_df["delivered_on_time"] = np.where(orders_df["order_delivered_customer_date"] <= orders_df["order_estimated_delivery_date"], "On Time", "Late")

# %%
orders_df.sample(10)
# Out:
#                                order_id                       customer_id  \
# 50824  cf6aa522d7b94b77f266075aa45f99af  83852335a70d85c548df6ba004ba9cda
# 25496  1c4b050b03674a68df8780c156a1e117  c0a8281c9a51b166d389f6ee6c144dd2
# 2353   daa1c13dd8df972cbc97ca351c67f32b  71e8560996119b529ab63d5a963f1a89
# 91065  0cadc06392b4f42042d688c35d6a1c16  a68c6b39ceff533ed6d5fc3a811880d9
# 46304  0f34e281521119381162d15a73510e3b  5db15d9a05ec6cd9a4279b8b5f23ede3
# 75277  f7adb52b8785594c7e357054489e371a  7c34219589e3983d508d3e782f0c18ff
# 35030  36af5b0b0ededbf6f30d1d809f05536b  7f4ca5e104cea64afdf3d68d84d4b520
# 13462  1cc1ac3bb7e6e9a7049ee81d4888dc4a  711464e4c54565256d2a20f481a8eead
# 19046  f5646e8203a36be7abc9ebb188926c39  218e8459e120553d778fa740d5785b0b
# 43111  0c02a4cb5207e682d63a1343cbddd13b  c68d0a3fbe7bf557ea9b8c822e154535
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 50824    delivered      2018-04-11 11:48:05 2018-04-12 08:15:12
# ...

# %%
#Product_cnt#

# %%
products_df.dropna(subset=["product_name_lenght", "product_description_lenght", "product_height_cm", "product_width_cm"], inplace=True)

# %%
products_df["product_category_name"].fillna(value="other", inplace=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_28876\1913382850.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   products_df["product_category_name"].fillna(value="other", inplace=True)

# %%
products_df["product_photos_qty"].fillna(value=0, inplace=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_28876\2075877112.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   products_df["product_photos_qty"].fillna(value=0, inplace=True)

# %%
products_df.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %%
#$EDA$#

# %%
geolocation_df.sample(10)
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 229985                         9400       -23.711524       -46.412998
# 951897                        92030       -29.910583       -51.145713
# 488950                        25716       -22.475897       -43.156116
# 659607                        39400       -16.721164       -43.859191
# 496575                        26278       -22.750482       -43.513687
# 94214                          4550       -23.603976       -46.678158
# 860867                        83203       -25.513868       -48.514384
# 276277                        12320       -23.316029       -45.982288
# 187299                         7178       -23.395872       -46.393877
# 823929                        78365       -13.551091       -58.824713
#
#        geolocation_city geolocation_state
# 229985   ribeirao pires                SP
# 951897           canoas                RS
# 488950       petropolis                RJ
# ...

# %%
geolocation_df.groupby(by="geolocation_zip_code_prefix").size().sort_values(ascending=False)
# Out:
# geolocation_zip_code_prefix
# 38400    779
# 35500    751
# 11680    727
# 11740    678
# 36400    627
#         ...
# 58403      1
# 1200       1
# 1189       1
# 1290       1
# 1262       1
# Length: 19015, dtype: int64

# %%
customers_df.sample(10)
# Out:
#                             customer_id                customer_unique_id  \
# 41054  a205407473078b5529f6654ae2d88729  dee7189ff497ea5803772e8a5c93db0c
# 79115  8fbbac627bea0879f8e10689ccc2993a  9fb23c0934b300ecec67d95926d1d09d
# 52245  d0296a9161a79996162a6a4f0835ed2d  a941c257a51188577ec66ddbeee21403
# 77748  2690e327b07f3f572c2cff4b828c266a  26d1739aa061131f1461646969d85f20
# 64703  525665779ff18323edab26a440601712  937c3941606c801c6e0fc1560ac4463a
# 65841  551105c58d9e76aaa04e67d90d1deff4  685cf6f21022e128820e898b197f7263
# 73263  48d13513873378a375f90baf4bb5834f  b5da5d0a329cf6e06dea9b309ecdc28c
# 16106  e029cab9b7ef3e78541646e7c261d67d  dc02867c21f42ed442f02e434234e3bb
# 47144  cad130498976053d343197781844dc38  e52db8b14f1a94725559dc98bca4767f
# 68358  0787afe87fbc7be9114a66325d1a5481  3845629d8ac15f4c0e482b5d68e608d8
#
#        customer_zip_code_prefix    customer_city customer_state
# 41054                     35500      divinopolis             MG
# ...

# %%
customers_df.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     274fa6071e5e17fe303b9748641082c8  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
customers_df.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# agisse                1
# vieiras               1
# bertopolis            1
# abadiania             1
# xexeu                 1
# Name: customer_id, Length: 4119, dtype: int64

# %%
customers_df.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %%
order_payments_df.sample(10)
# Out:
#                                order_id  payment_sequential payment_type  \
# 24830  fed5acc964b83f6c02d8bc487c76fa96                   1  credit_card
# 70964  610d2254a191363a1f87185789c63231                   1       boleto
# 59008  84d1f58195cae334b50f9088b38b3495                   1  credit_card
# 38476  fc5a67aa2d57b1764a89718edf876006                   1  credit_card
# 78693  cd994d365e6a5dcaa94ff5f3fadb0ad8                   1       boleto
# 75191  3cb69ccd08eea344a68a66e8ce49a282                   1  credit_card
# 57739  ded0d9b3df9ac8d6ea99bc2f88762481                   1   debit_card
# 49726  b30f6677ba659390857271ffd12c0d29                   1  credit_card
# 42647  d1703ba698d30bb04a48f0238c79c066                   1  credit_card
# 38259  a4c94baa526c2e39251e807cda61c524                   1  credit_card
#
#        payment_installments  payment_value
# 24830                     2          45.78
# 70964                     1          40.78
# ...

# %%
order_payments_df.groupby(by="payment_type").order_id.nunique().sort_values(ascending=False)
# Out:
# payment_type
# credit_card    76505
# boleto         19784
# voucher         3866
# debit_card      1528
# not_defined        3
# Name: order_id, dtype: int64

# %%
orders_df.sample(10)
# Out:
#                                order_id                       customer_id  \
# 27767  17b7c2f3241fc2ef8e7f7a3b916993e3  2d598740458ddd8adf4d639fe801f902
# 72468  931518b84759d4344b33cace70b70a21  e04f75016199b36d84cdc8fb3763c991
# 14862  5226003c0580585a8fe4e9b6d2935c2a  1dbf434ac2c0271c0a5222be25c8fe62
# 9434   97bc7ca0c3993c893f4fd5199e2ae2e8  f4a71d716969f02d7762087de2b32ed1
# 7430   524e1be52afa977f77d263a35041c19f  338de346d6930edcf0808e2d45d13652
# 15681  7a1bca69f79d87467a917e1fdc8cda7e  5cf22a974923bb5a481327e3d2a0dbd3
# 5987   6af5a09bae161896af1bd1d4a83a39ce  765c5a44d2bee479336e965c39e85f13
# 27781  05cd156f0f47579a36d7a52724fc31b8  976224a95faf328b17654b1b1411d5e1
# 25157  103a6df3372464e08e529f7d888a48f6  7a9915a7ff0cd1ba1f13318f84d1a7f2
# 79247  5e2c33d2f30f75167981f86a98b727cf  6a747a9382486708e3501030fbfdbd3c
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 27767    delivered      2018-05-23 17:51:24 2018-05-23 18:17:05
# ...

# %%
orders_df["delivered_on_time"].value_counts()
# Out:
# delivered_on_time
# On Time    88630
# Late        7825
# Name: count, dtype: int64

# %%
customers_orders_df = pd.merge(
    left=customers_df,
    right=orders_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
customers_orders_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
payments_reviews_df = pd.merge(
    left=order_payments_df,
    right=order_reviews_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
payments_reviews_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
#
#    payment_installments  payment_value                         review_id  \
# 0                     8          99.33  4ce650e117a5b292bf5ea980a61eb61e
# 1                     1          24.39  ad2036caca61484fc435d7e673c020f2
# 2                     1          65.71  bcddfa0f7d2e54cfc74bae4f01b84d92
# 3                     8         107.78  c37a0e51e5df82bdb55d38ff0ffb6af3
# 4                     8         107.78  5bc7680443b4ef765fec11a8201eeb0c
#
#    review_score                             review_comment_message  \
# ...

# %%
payments_reviews_df.sort_values(by="payment_value", ascending=False)
# Out:
#                                order_id  payment_sequential payment_type  \
# 52415  03caa2c082116e1d31e67e9ae3700499                   1  credit_card
# 34565  736e1922ae60d0d6a89247b851902527                   1       boleto
# 41660  0812eb902a67711a1cb742b3cdaa65ae                   1  credit_card
# 49871  fefacc66af859508bf1a7934eab1e97f                   1       boleto
# 86018  f5136e38d1a14a4dbd87dff67da82701                   1       boleto
# ...                                 ...                 ...          ...
# 37030  fa65dad1b0e818e3ccc5cb0e39231352                  14      voucher
# 78326  fa65dad1b0e818e3ccc5cb0e39231352                  13      voucher
# 51581  4637ca194b6387e2d538dc89b124b0ee                   1  not_defined
# 57753  00b1cb0320190ca0daa2c88b35206009                   1  not_defined
# 94953  c8c528189310eaa44a745b8d9d26908b                   1  not_defined
#
#        payment_installments  payment_value                         review_id  \
# ...

# %%
payments_reviews_df.groupby(by="payment_type").agg({
    "order_id": "nunique",
    "payment_value": ["min", "max"]
})
# Out:
#              order_id payment_value
#               nunique           min       max
# payment_type
# boleto          19784         11.62   7274.88
# credit_card     76505          0.01  13664.08
# debit_card       1528         13.38   4445.50
# not_defined         3          0.00      0.00
# voucher          3866          0.00   3184.34

# %%
cust_df = pd.merge(
    left=customers_orders_df,
    right=payments_reviews_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
cust_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
items_sellers_df = pd.merge(
    left=order_items_df,
    right=sellers_df,
    how="left",
    left_on="seller_id",
    right_on="seller_id"
)
items_sellers_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  seller_zip_code_prefix  \
# 0 2017-09-19 09:45:35   58.90          13.29                   27277
# 1 2017-05-03 11:05:13  239.90          19.93                    3471
# ...

# %%
items_sellers_df.groupby(by="seller_city").seller_id.nunique().sort_values(ascending=False).head(10)
# Out:
# seller_city
# sao paulo         694
# curitiba          127
# rio de janeiro     96
# belo horizonte     68
# ribeirao preto     52
# guarulhos          50
# ibitinga           49
# santo andre        45
# campinas           41
# maringa            40
# Name: seller_id, dtype: int64

# %%
items_sellers_df.groupby(by="seller_state").seller_id.nunique().sort_values(ascending=False).head(10)
# Out:
# seller_state
# SP    1849
# PR     349
# MG     244
# SC     190
# RJ     171
# RS     129
# GO      40
# DF      30
# ES      23
# BA      19
# Name: seller_id, dtype: int64

# %%
products_category_df = pd.merge(
    left=products_df,
    right=product_cnt_df,
    how="left",
    left_on="product_category_name",
    right_on="product_category_name"
)
products_category_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %%
products_category_df.groupby(by="product_category_name").product_id.nunique().sort_values(ascending=False).head(10)
# Out:
# product_category_name
# cama_mesa_banho           3029
# esporte_lazer             2867
# moveis_decoracao          2657
# beleza_saude              2444
# utilidades_domesticas     2335
# automotivo                1900
# informatica_acessorios    1639
# brinquedos                1411
# relogios_presentes        1329
# telefonia                 1134
# Name: product_id, dtype: int64

# %%
products_category_df.groupby(by="product_category_name_english").product_id.nunique().sort_values(ascending=False).head(10)
# Out:
# product_category_name_english
# bed_bath_table           3029
# sports_leisure           2867
# furniture_decor          2657
# health_beauty            2444
# housewares               2335
# auto                     1900
# computers_accessories    1639
# toys                     1411
# watches_gifts            1329
# telephony                1134
# Name: product_id, dtype: int64

# %%
sellers_merge_df = pd.merge(
    left=products_category_df,
    right=items_sellers_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
sellers_merge_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %%
sellers_merge_df.sort_values(by="price", ascending=False)
# Out:
#                              product_id              product_category_name  \
# 20259  489ae2aa008f021502940f251d4cce7f              utilidades_domesticas
# 72948  69c590f7ffc7bf8db97190b6cb6ed62e                                pcs
# 48843  1bdf5e6731585cf01aa8169c7028d6ad                              artes
# 70869  a6492cc69376c469ab6f61d8f44de961                    eletroportateis
# 31828  c3ed642d592594bb648ff4a04cee2747                    eletroportateis
# ...                                 ...                                ...
# 55171  05b515fdc76e888aada3c6d66c201dff                       beleza_saude
# 55175  05b515fdc76e888aada3c6d66c201dff                       beleza_saude
# 29221  8a3254bee785a526d548a81a9bc3c9be  construcao_ferramentas_construcao
# 29223  8a3254bee785a526d548a81a9bc3c9be  construcao_ferramentas_construcao
# 29222  8a3254bee785a526d548a81a9bc3c9be  construcao_ferramentas_construcao
#
# ...

# %%
sellers_merge_df.groupby(by="product_category_name_english").agg({
    "order_id": "nunique",
    "price":  ["min", "max"]
})
# Out:
#                               order_id  price
#                                nunique    min      max
# product_category_name_english
# agro_industry_and_commerce         182  12.99  2990.00
# air_conditioning                   253  10.90  1599.00
# art                                202   3.50  6499.00
# arts_and_craftmanship               23   9.80   289.49
# audio                              350  14.90   598.99
# ...                                ...    ...      ...
# stationery                        2311   2.29  1693.00
# tablets_printing_image              79  14.90   889.99
# telephony                         4199   5.00  2428.00
# toys                              3886   4.90  1699.99
# watches_gifts                     5624   8.99  3999.90
#
# [71 rows x 3 columns]

# %%
all_data = pd.merge(
    left=cust_df,
    right=sellers_merge_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
all_data.head(20)
# Out:
#                          customer_id                customer_unique_id  \
# 0   06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1   18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2   4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3   b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4   4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# 5   879864dab9bc3047522c92c82e1212b8  4c93744516667ad3b8f1fb645a3116a4
# 6   fd826e7cf63160e536e0908c76c3f441  addec96d2e059c80c30fe6871d30d177
# 7   5e274e7a0c3809e14aba7ad5aae0d407  57b2a98a409812fe9618067b6b8ebe4f
# 8   5adf08e34b2e993982a47070956c5c65  1175e95fb47ddff9de6b2b06188f7e0d
# 9   4b7139f34592b3a31687243a302fa75b  9afe194fb833f79e300e37e580171f22
# 10  9fb35e4ed6f0a14a4977cd9aea4042bb  2a7745e1ed516b289ed9b29c7d0539a5
# 11  5aa9e4fdd4dfd20959cad2d772509598  2a46fb94aef5cbeeb850418118cee090
# ...

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118467 entries, 0 to 118466
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   customer_id                    118467 non-null  object
#  1   customer_unique_id             118467 non-null  object
#  2   customer_zip_code_prefix       118467 non-null  int64
#  3   customer_city                  118467 non-null  object
#  4   customer_state                 118467 non-null  object
#  5   order_id                       115481 non-null  object
#  6   order_status                   115481 non-null  object
#  7   order_purchase_timestamp       115481 non-null  datetime64[ns]
#  8   order_approved_at              115481 non-null  datetime64[ns]
#  9   order_delivered_carrier_date   115481 non-null  datetime64[ns]
#  10  order_delivered_customer_date  115481 non-null  datetime64[ns]
# ...

# %%
all_data.drop_duplicates(inplace=True)
all_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
all_data.groupby(by="customer_state").agg({
    "order_id": "nunique",
    "payment_value": "sum"
}).sort_values(by="payment_value", ascending=False)
# Out:
#                 order_id  payment_value
# customer_state
# SP                 40488     7434677.68
# RJ                 12348     2694177.84
# MG                 11351     2287776.67
# RS                  5342     1108280.99
# PR                  4923     1034601.30
# BA                  3256      772423.42
# SC                  3546      768405.87
# GO                  1957      496426.61
# DF                  2080      424613.99
# ES                  1995      399201.58
# PE                  1593      361363.59
# CE                  1278      332168.11
# PA                   946      255327.31
# MT                   886      251859.09
# MA                   716      195191.60
# PB                   517      177320.00
# MS                   701      164556.97
# PI                   476      133729.03
# RN                   474      115203.08
# AL                   397      108727.76
# SE                   335       85694.32
# TO                   274       70780.74
# ...

# %%
all_data.groupby(by="product_category_name_english").agg({
    "order_id": "nunique",
    "review_score":  ["min", "max"]
})
# Out:
#                               order_id review_score
#                                nunique          min  max
# product_category_name_english
# agro_industry_and_commerce         177          1.0  5.0
# air_conditioning                   246          1.0  5.0
# art                                195          1.0  5.0
# arts_and_craftmanship               23          1.0  5.0
# audio                              348          1.0  5.0
# ...                                ...          ...  ...
# stationery                        2264          1.0  5.0
# tablets_printing_image              79          1.0  5.0
# telephony                         4092          1.0  5.0
# toys                              3803          1.0  5.0
# watches_gifts                     5493          1.0  5.0
#
# [71 rows x 3 columns]

# %%
all_data.to_csv("all_data.csv", index=False)

# %%
monthly_orders = all_data.resample(rule='M', on='order_approved_at').agg({
    "order_id": "nunique",
    "payment_value": "sum"
})
monthly_orders.index = monthly_orders.index.strftime('%B')
monthly_orders = monthly_orders.reset_index()
monthly_orders.rename(columns={
    "order_approved_at": "order_date",
    "order_id": "order_count",
    "payment_value": "revenue"
}, inplace=True)
monthly_orders
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_28876\690134396.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_orders = all_data.resample(rule='M', on='order_approved_at').agg({
#    order_date  order_count     revenue
# 0   September            1        0.00
# 1     October          265    62185.82
# 2    November            0        0.00
# 3    December            1       19.62
# 4     January          715   171054.49
# 5    February         1638   325381.93
# 6       March         2554   505582.49
# 7       April         2278   450650.20
# 8         May         3547   705181.88
# 9        June         3143   594915.16
# 10       July         3828   710030.63
# 11     August         4217   849996.67
# 12  September         4169   897290.35
# 13    October         4441  1096194.24
# 14   November         7149  1536858.63
# 15   December         5675  1054699.20
# 16    January         6991  1357598.89
# ...

# %%
monthly_orders = monthly_orders.sort_values("order_count").drop_duplicates("order_date", keep='last')

# %%
monthly_orders.sort_values(by="order_count", ascending=False)
# Out:
#    order_date  order_count     revenue
# 14   November         7149  1536858.63
# 18      March         7083  1452494.81
# 16    January         6991  1357598.89
# 20        May         6940  1513867.69
# 19      April         6639  1443732.48
# 17   February         6536  1280434.93
# 23     August         6504  1246443.51
# 21       June         6094  1292834.76
# 22       July         6047  1281816.75
# 15   December         5675  1054699.20
# 13    October         4441  1096194.24
# 12  September         4169   897290.35

# %%
months_order = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]
monthly_orders["order_date"] = pd.Categorical(monthly_orders["order_date"], categories=months_order, ordered=True)
monthly_orders = monthly_orders.sort_values("order_date")

plt.figure(figsize=(10,5))
plt.plot(monthly_orders["order_date"], monthly_orders["order_count"], marker="o", linewidth=2, color="#72BCD4")
plt.title("Jumlah Pesanan per Bulan (2018)", loc="center", fontsize=14)
plt.xlabel("Month", fontsize=12)
plt.ylabel("Jumlah Pesanan", fontsize=12)
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
bycity = all_data['customer_city'].value_counts().head(10)

plt.figure(figsize=(12, 6))

most_common_city = bycity.idxmax()

bycity = bycity.sort_values(ascending=False)

sns.barplot(x=bycity.index,
            y=bycity.values,
            palette=["#068DA9" if city == most_common_city else "#D3D3D3" for city in bycity.index]
            )

plt.title("Jumlah Pelanggan Berdasarkan Kota", fontsize=15)
plt.xlabel("Kota")
plt.ylabel("Jumlah Pelanggan")
plt.xticks(rotation=45, fontsize=10)
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_28876\3765666439.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=bycity.index,

# %%
bystate = all_data['customer_state'].value_counts().head(10)

plt.figure(figsize=(12, 6))

most_common_city = bystate.idxmax()

bystate = bystate.sort_values(ascending=False)

sns.barplot(x=bystate.index,
            y=bystate.values,
            palette=["#068DA9" if city == most_common_city else "#D3D3D3" for city in bystate.index]
            )

plt.title("Jumlah Pelanggan Berdasarkan State", fontsize=15)
plt.xlabel("State")
plt.ylabel("Jumlah Pelanggan")
plt.xticks(rotation=45, fontsize=10)
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_28876\3120609460.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=bystate.index,
